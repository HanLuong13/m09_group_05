# %%
from sklearn.cluster import DBSCAN
from sklearn import metrics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
import seaborn as sns

# %%
df = pd.read_csv('animals-dataset.csv')

# %%
df.head(15)
# Out:
#     Region               Stage Individual ID  Culmen Length (mm)  \
# 0   Anvers  Adult, 1 Egg Stage          N1A1                39.1
# 1   Anvers  Adult, 1 Egg Stage          N1A2                39.5
# 2   Anvers  Adult, 1 Egg Stage          N2A1                40.3
# 3   Anvers  Adult, 1 Egg Stage          N2A2                 NaN
# 4   Anvers  Adult, 1 Egg Stage          N3A1                36.7
# 5   Anvers  Adult, 1 Egg Stage          N3A2                39.3
# 6   Anvers  Adult, 1 Egg Stage          N4A1                38.9
# 7   Anvers  Adult, 1 Egg Stage          N4A2                39.2
# 8   Anvers  Adult, 1 Egg Stage          N5A1                34.1
# 9   Anvers  Adult, 1 Egg Stage          N5A2                42.0
# 10  Anvers  Adult, 1 Egg Stage          N6A1                37.8
# 11  Anvers  Adult, 1 Egg Stage          N6A2                37.8
# 12  Anvers  Adult, 1 Egg Stage          N7A1                41.1
# 13  Anvers  Adult, 1 Egg Stage          N7A2                38.6
# 14  Anvers  Adult, 1 Egg Stage          N8A1                34.6
#
#     Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# 0                18.7                181.0         3750.0                NaN
# 1                17.4                186.0         3800.0            8.94956
# 2                18.0                195.0         3250.0            8.36821
# 3                 NaN                  NaN            NaN                NaN
# 4                19.3                193.0         3450.0            8.76651
# 5                20.6                190.0         3650.0            8.66496
# 6                17.8                181.0         3625.0            9.18718
# 7                19.6                195.0         4675.0            9.46060
# 8                18.1                193.0         3475.0                NaN
# 9                20.2                190.0         4250.0            9.13362
# 10               17.1                186.0         3300.0            8.63243
# 11               17.3                180.0         3700.0                NaN
# 12               17.6                182.0         3200.0                NaN
# 13               21.2                191.0         3800.0                NaN
# 14               21.1                198.0         4400.0            8.55583
#
#     Delta 13 C (o/oo)                               Comments
# 0                 NaN         Not enough blood for isotopes.
# 1           -24.69454                                    NaN
# 2           -25.33302                                    NaN
# 3                 NaN                     Adult not sampled.
# 4           -25.32426                                    NaN
# 5           -25.29805                                    NaN
# 6           -25.21799  Nest never observed with full clutch.
# 7           -24.89958  Nest never observed with full clutch.
# 8                 NaN              No blood sample obtained.
# 9           -25.09368   No blood sample obtained for sexing.
# 10          -25.21315   No blood sample obtained for sexing.
# 11                NaN              No blood sample obtained.
# 12                NaN         Not enough blood for isotopes.
# 13                NaN         Not enough blood for isotopes.
# 14          -25.22588                                    NaN

# %%
print(df['Region'].unique())
print(df['Stage'].unique())
print(df['Individual ID'].unique())
print(df['Culmen Length (mm)'].unique())
# Out:
# ['Anvers']
# ['Adult, 1 Egg Stage']
# ['N1A1' 'N1A2' 'N2A1' 'N2A2' 'N3A1' 'N3A2' 'N4A1' 'N4A2' 'N5A1' 'N5A2'
#  'N6A1' 'N6A2' 'N7A1' 'N7A2' 'N8A1' 'N8A2' 'N9A1' 'N9A2' 'N10A1' 'N10A2'
#  'N11A1' 'N11A2' 'N12A1' 'N12A2' 'N13A1' 'N13A2' 'N17A1' 'N17A2' 'N18A1'
#  'N18A2' 'N21A1' 'N21A2' 'N22A1' 'N22A2' 'N23A1' 'N23A2' 'N24A1' 'N24A2'
#  'N25A1' 'N25A2' 'N26A1' 'N26A2' 'N27A1' 'N27A2' 'N28A1' 'N28A2' 'N29A1'
#  'N29A2' 'N30A1' 'N30A2' 'N32A1' 'N32A2' 'N34A1' 'N34A2' 'N35A1' 'N35A2'
#  'N36A1' 'N36A2' 'N37A1' 'N37A2' 'N38A1' 'N38A2' 'N39A1' 'N39A2' 'N40A1'
#  'N40A2' 'N41A1' 'N41A2' 'N42A1' 'N42A2' 'N44A1' 'N44A2' 'N45A1' 'N45A2'
#  'N46A1' 'N46A2' 'N48A1' 'N48A2' 'N49A1' 'N49A2' 'N50A1' 'N50A2' 'N47A1'
#  'N47A2' 'N51A1' 'N51A2' 'N53A1' 'N53A2' 'N55A1' 'N55A2' 'N58A1' 'N58A2'
#  'N60A1' 'N60A2' 'N61A1' 'N61A2' 'N63A1' 'N63A2' 'N64A1' 'N64A2' 'N66A1'
#  'N66A2' 'N67A1' 'N67A2' 'N69A1' 'N69A2' 'N71A1' 'N71A2' 'N72A1' 'N72A2'
#  'N73A1' 'N73A2' 'N76A1' 'N76A2' 'N77A1' 'N77A2' 'N78A1' 'N78A2' 'N79A1'
#  'N79A2' 'N80A1' 'N80A2' 'N81A1' 'N81A2' 'N82A1' 'N82A2' 'N83A1' 'N83A2'
#  'N84A1' 'N84A2' 'N85A1' 'N85A2' 'N62A1' 'N62A2' 'N68A1' 'N68A2' 'N70A1'
#  'N70A2' 'N89A1' 'N89A2' 'N65A1' 'N65A2' 'N74A1' 'N74A2' 'N75A1' 'N75A2'
#  'N86A1' 'N86A2' 'N87A1' 'N87A2' 'N88A1' 'N88A2' 'N90A1' 'N90A2' 'N92A1'
#  'N92A2' 'N93A1' 'N93A2' 'N94A1' 'N94A2' 'N95A1' 'N95A2' 'N96A1' 'N96A2'
#  'N98A1' 'N98A2' 'N99A1' 'N99A2' 'N100A1' 'N100A2' 'N31A1' 'N31A2' 'N33A1'
#  'N33A2' 'N56A1' 'N56A2' 'N14A1' 'N14A2' 'N15A1' 'N15A2' 'N16A1' 'N16A2'
#  'N19A1' 'N19A2' 'N20A1' 'N20A2' 'N54A1' 'N54A2' 'N43A1' 'N43A2']
# [39.1 39.5 40.3  nan 36.7 39.3 38.9 39.2 34.1 42.  37.8 41.1 38.6 34.6
#  36.6 38.7 42.5 34.4 46.  37.7 35.9 38.2 38.8 35.3 40.6 40.5 37.9 37.2
#  40.9 36.4 42.2 37.6 39.8 36.5 40.8 36.  44.1 37.  39.6 37.5 42.3 40.1
#  35.  34.5 41.4 39.  35.7 41.3 41.6 35.5 41.8 33.5 39.7 45.8 42.8 36.2
#  42.1 42.9 35.1 37.3 36.3 36.9 38.3 34.  38.1 33.1 43.2 41.  45.6 42.7
#  40.2 35.2 41.5 38.5 43.1 36.8 35.6 32.1 40.7 46.5 50.  51.3 45.4 52.7
#  45.2 46.1 46.6 51.7 47.  52.  45.9 50.5 50.3 58.  46.4 49.2 42.4 48.5
#  50.6 46.7 49.5 52.8 54.2 51.  49.7 47.5 47.6 46.9 53.5 49.  46.2 50.9
#  45.5 50.8 50.1 51.5 49.8 48.1 51.4 45.7 50.7 52.2 49.3 50.2 51.9 46.8
#  55.8 43.5 49.6 48.7 43.3 48.4 45.1 46.3 44.5 47.8 48.2 47.3 59.6 49.1
#  42.6 44.4 44.  45.3 43.6 44.9 45.  43.8 50.4 54.3 47.7 48.6 51.1 52.5
#  47.4 43.4 52.1 49.4 55.9 47.2 41.7 53.4 55.1 48.8 49.9]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Region               344 non-null    object
#  1   Stage                344 non-null    object
#  2   Individual ID        344 non-null    object
#  3   Culmen Length (mm)   342 non-null    float64
#  4   Culmen Depth (mm)    342 non-null    float64
#  5   Flipper Length (mm)  342 non-null    float64
#  6   Body Mass (g)        342 non-null    float64
#  7   Delta 15 N (o/oo)    330 non-null    float64
#  8   Delta 13 C (o/oo)    331 non-null    float64
#  9   Comments             26 non-null     object
# dtypes: float64(6), object(4)
# memory usage: 27.0+ KB

# %%
df.shape
# Out:
# (344, 10)

# %%
df.isna().sum()
# Out:
# Region                   0
# Stage                    0
# Individual ID            0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               318
# dtype: int64

# %%
#Dropping columns that have categorical data
df.drop(columns=['Region', 'Stage', 'Individual ID', 'Comments'], inplace=True)

# %%
#Dropping columns that have null values
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 4                36.7               19.3                193.0         3450.0
# 5                39.3               20.6                190.0         3650.0
# 6                38.9               17.8                181.0         3625.0
#
#    Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 1            8.94956          -24.69454
# 2            8.36821          -25.33302
# 4            8.76651          -25.32426
# 5            8.66496          -25.29805
# 6            9.18718          -25.21799

# %%
print(df['Culmen Length (mm)'].unique())
# Out:
# [39.5 40.3 36.7 39.3 38.9 39.2 42.  37.8 34.6 38.7 42.5 34.4 46.  37.7
#  35.9 38.2 38.8 35.3 40.6 40.5 37.9 37.2 40.9 36.4 42.2 37.6 36.5 36.
#  44.1 37.  39.6 42.3 40.1 35.  34.5 41.4 39.  35.7 41.3 41.1 41.6 35.5
#  41.8 33.5 39.7 45.8 42.8 36.2 42.1 42.9 35.1 37.3 36.3 36.9 38.3 34.
#  40.8 38.1 33.1 43.2 41.  38.6 45.6 42.7 40.2 35.2 41.5 38.5 43.1 36.8
#  37.5 35.6 32.1 40.7 36.6 46.5 50.  51.3 45.4 52.7 45.2 46.1 46.6 51.7
#  47.  52.  45.9 50.5 50.3 58.  46.4 49.2 42.4 48.5 50.6 46.7 49.5 52.8
#  54.2 51.  49.7 47.5 47.6 46.9 53.5 49.  46.2 50.9 45.5 50.8 50.1 51.5
#  49.8 48.1 51.4 45.7 50.7 52.2 49.3 50.2 46.8 55.8 43.5 49.6 48.7 43.3
#  48.4 45.1 46.3 44.5 47.8 48.2 59.6 49.1 42.6 44.4 44.  45.3 43.6 44.9
#  45.  43.8 50.4 54.3 47.7 48.6 51.1 52.5 47.4 43.4 52.1 49.4 55.9 47.2
#  47.3 41.7 53.4 55.1 48.8 49.9]
